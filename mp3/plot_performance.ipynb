# %%
import numpy as np
import matplotlib.pyplot as plt

# Given arrays
array1 = [0.87, 0.76, 0.79, 0.93, 0.85]
array2 = [0.46, 0.53, 0.50, 0.51, 0.41]
array3 = [0.21, 0.23, 0.22, 0.21, 0.21]
array4 = [0.1, 0.09, 0.12, 0.1, 0.1]
array5 = [0.017, 0.034, 0.023, 0.036, 0.015]



# Compute average (mean) and standard deviation
mean1 = np.mean(array1)
std_dev1 = np.std(array1)

mean2 = np.mean(array2)
std_dev2 = np.std(array2)

mean3 = np.mean(array3)
std_dev3 = np.std(array3)

mean4 = np.mean(array4)
std_dev4 = np.std(array4)

mean5 = np.mean(array5)
std_dev5 = np.std(array5)

# Data for plotting
labels = ['100MB', '50MB', '20MB', '5MB', '1MB']

means = [mean1, mean2, mean3, mean4, mean5]
std_devs = [std_dev1, std_dev2, std_dev3, std_dev4, std_dev5]

# Plotting
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, means, width, label='Bandwidth', yerr=std_devs, capsize=5, color=['orange'])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('File Size')
ax.set_ylabel('second')
ax.set_title('Re-replication Time')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar in *rects*, displaying its height and standard deviation.
def autolabel(rects, std_devs):
    """Attach a text label above each bar in *rects*, displaying its height and standard deviation."""
    for rect, std_dev in zip(rects, std_devs):
        height = rect.get_height()
        ax.annotate(f'{round(height, 2)}\n±{round(std_dev, 2)}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(rects1, std_devs)

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given arrays
array1 = [121, 112, 118, 124, 125]
array2 = [115, 116, 114, 117, 115]
array3 = [108, 109, 107, 108, 109]
array4 = [109, 112, 104, 108, 107]
array5 = [61, 73, 58, 64, 63]

# Compute average (mean) and standard deviation
mean1 = np.mean(array1)
std_dev1 = np.std(array1)

mean2 = np.mean(array2)
std_dev2 = np.std(array2)

mean3 = np.mean(array3)
std_dev3 = np.std(array3)

mean4 = np.mean(array4)
std_dev4 = np.std(array4)

mean5 = np.mean(array5)
std_dev5 = np.std(array5)

# Data for plotting
labels = ['100MB', '50MB', '20MB', '5MB', '1MB']

means = [mean1, mean2, mean3, mean4, mean5]
std_devs = [std_dev1, std_dev2, std_dev3, std_dev4, std_dev5]

# Plotting
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, means, width, label='Bandwidth', yerr=std_devs, capsize=5, color=['orange'])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('File Size')
ax.set_ylabel('MB/s')
ax.set_title('Re-replication Bandwidth')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar in *rects*, displaying its height and standard deviation.
def autolabel(rects, std_devs):
    """Attach a text label above each bar in *rects*, displaying its height and standard deviation."""
    for rect, std_dev in zip(rects, std_devs):
        height = rect.get_height()
        ax.annotate(f'{round(height, 2)}\n±{round(std_dev, 2)}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(rects1, std_devs)

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given arrays
array1 = [133.2, 121.5, 124.1, 138.6, 131.2]
array2 = [321.5, 342.6, 312.1, 363.7, 348.3]
array3 = [132.1, 123.4, 143.2, 129.4, 134.2]
array4 = [323.1, 342.1, 313.2, 365.2, 351.2]
array5 = [131.7, 124.9, 141.6, 130.2, 135.1]
array6 = [322.6, 344.3, 315.5, 362.7, 349.0]
array7 = [131.2, 124.5, 142.1, 129.6, 134.5]
array8 = [320.5, 341.5, 312.4, 363.2, 350.3]



# Compute average (mean) and standard deviation
mean1 = np.mean(array1)
std_dev1 = np.std(array1)

mean2 = np.mean(array2)
std_dev2 = np.std(array2)

mean3 = np.mean(array3)
std_dev3 = np.std(array3)

mean4 = np.mean(array4)
std_dev4 = np.std(array4)

mean5 = np.mean(array5)
std_dev5 = np.std(array5)

mean6 = np.mean(array6)
std_dev6 = np.std(array6)

mean7 = np.mean(array7)
std_dev7 = np.std(array7)

mean8 = np.mean(array8)
std_dev8 = np.std(array8)

# Data for plotting
labels = ['4/1', '40/1', '4/2', '40/2', '4/5', '40/5', '4/10', '40/10']

means = [mean1, mean2, mean3, mean4, mean5, mean6, mean7, mean8]
std_devs = [std_dev1, std_dev2, std_dev3, std_dev4, std_dev5, std_dev6, std_dev7, std_dev8]

# Plotting
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, means, width, label='Bandwidth', yerr=std_devs, capsize=5, color=['orange'])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('File Size(KB)/machine count')
ax.set_ylabel('ms')
ax.set_title('Merge Time')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar in *rects*, displaying its height and standard deviation.
def autolabel(rects, std_devs):
    """Attach a text label above each bar in *rects*, displaying its height and standard deviation."""
    for rect, std_dev in zip(rects, std_devs):
        height = rect.get_height()
        ax.annotate(f'{round(height, 2)}\n±{round(std_dev, 2)}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(rects1, std_devs)

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given arrays
array1 = [28.71, 29.03, 28.12, 27.87, 28.22]
array2 = [27.77, 27.28, 28.29, 26.77, 25.07]
array3 = [20.12, 20.71, 18.78, 18.5, 19.78]
array4 = [9.12, 9.78, 9.5, 9.78, 9.12]
array5 = [3.21, 3.12, 3.21, 3.21, 3.21]


array1 = [28.23, 28.75, 29.11, 27.98, 28.42]
array2 = [25.89, 26.74, 27.12, 26.01, 25.55]
array3 = [14.89, 15.67, 15.32, 14.77, 15.01]
array4 = [4.69, 4.34, 4.14, 4.89, 4.23]
array5 = [3.34, 3.05, 3.13, 3.58, 2.98]


# Compute average (mean) and standard deviation
mean1 = np.mean(array1)
std_dev1 = np.std(array1)

mean2 = np.mean(array2)
std_dev2 = np.std(array2)

mean3 = np.mean(array3)
std_dev3 = np.std(array3)

mean4 = np.mean(array4)
std_dev4 = np.std(array4)

mean5 = np.mean(array5)
std_dev5 = np.std(array5)

# Data for plotting
labels = ['0%', '10%', '20%', '50%', '100%']

means = [mean1, mean2, mean3, mean4, mean5]
std_devs = [std_dev1, std_dev2, std_dev3, std_dev4, std_dev5]

# Plotting
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, means, width, label='Bandwidth', yerr=std_devs, capsize=5, color=['orange'])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Cache Size')
ax.set_ylabel('second')
# ax.set_title('Query Time (Random Query)')
ax.set_title('Query Time (Frequent Query)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar in *rects*, displaying its height and standard deviation.
def autolabel(rects, std_devs):
    """Attach a text label above each bar in *rects*, displaying its height and standard deviation."""
    for rect, std_dev in zip(rects, std_devs):
        height = rect.get_height()
        ax.annotate(f'{round(height, 2)}\n±{round(std_dev, 2)}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(rects1, std_devs)

fig.tight_layout()

plt.show()
